# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=54d0c86b911ed7fc26968a52ab3067e7

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Discription" : city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kudymkar
# Processing Record 2 of Set 1 | doha
# Processing Record 3 of Set 1 | ancud
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | bairiki
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | jiaocheng
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | tuatapere
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | innisfail
# Processing Record 18 of Set 1 | champerico
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | livingston
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | southend-on-sea
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | bar harbor
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | nong phai
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | meulaboh
# Processing Record 36 of Set 1 | santa cruz
# Processing Record 37 of Set 1 | kirakira
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | lokoja
# Processing Record 42 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 1 | broome
# Processing Record 44 of Set 1 | hutchinson
# Processing Record 45 of Set 1 | hami
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | labuhan
# Processing Record 48 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 1 | quime
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | tarakan
# Processing Record 2 of Set 2 | barcelos
# Processing Record 3 of Set 2 | pringsewu
# Processing Record 4 of Set 2 | lasa
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | mount isa
# Processing Record 8 of Set 2 | marsa matruh
# Processing Record 9 of Set 2 | padang
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | santa rita
# Processing Record 12 of Set 2 | nome
# Processing Record 13 of Set 2 | santa isabel
# Processing Record 14 of Set 2 | ribeira brava
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | kamienna gora
# Processing Record 20 of Set 2 | dharchula
# Processing Record 21 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 2 | san policarpo
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | itarema
# Processing Record 25 of Set 2 | robertsport
# Processing Record 26 of Set 2 | leningradskiy
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | iglesias
# Processing Record 32 of Set 2 | vanimo
# Processing Record 33 of Set 2 | nizhniy ingash
# Processing Record 34 of Set 2 | vossevangen
# Processing Record 35 of Set 2 | meiganga
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | andenes
# Processing Record 38 of Set 2 | gallup
# Processing Record 39 of Set 2 | nemuro
# Processing Record 40 of Set 2 | kargopol
# Processing Record 41 of Set 2 | chardara
# Processing Record 42 of Set 2 | sal rei
# Processing Record 43 of Set 2 | poniatowa
# Processing Record 44 of Set 2 | zhoucheng
# Processing Record 45 of Set 2 | palmer
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | bijawar
# Processing Record 49 of Set 2 | havoysund
# Processing Record 50 of Set 2 | qaqortoq
# Processing Record 1 of Set 3 | kloulklubed
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | pilar
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | novobirilyussy
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | daloa
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | popondetta
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | dicabisagan
# Processing Record 17 of Set 3 | zaprudnya
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | harper
# Processing Record 22 of Set 3 | palana
# Processing Record 23 of Set 3 | college
# Processing Record 24 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | touho
# Processing Record 27 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 3 | ulladulla
# Processing Record 29 of Set 3 | tukrah
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | nabinagar
# Processing Record 32 of Set 3 | lorengau
# Processing Record 33 of Set 3 | hereford
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | kifri
# Processing Record 36 of Set 3 | rio gallegos
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | whitehorse
# Processing Record 39 of Set 3 | makakilo city
# Processing Record 40 of Set 3 | kodinsk
# Processing Record 41 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | saint andrews
# Processing Record 44 of Set 3 | sisimiut
# Processing Record 45 of Set 3 | sandnessjoen
# Processing Record 46 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 3 | pemangkat
# Processing Record 48 of Set 3 | camargo
# Processing Record 49 of Set 3 | batagay
# Processing Record 50 of Set 3 | carutapera
# Processing Record 1 of Set 4 | watertown
# Processing Record 2 of Set 4 | kabinda
# Processing Record 3 of Set 4 | gull lake
# Processing Record 4 of Set 4 | macenta
# Processing Record 5 of Set 4 | mananara
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | alofi
# Processing Record 8 of Set 4 | bengkulu
# Processing Record 9 of Set 4 | mena
# Processing Record 10 of Set 4 | ixtapa
# Processing Record 11 of Set 4 | bonito
# Processing Record 12 of Set 4 | saskylakh
# Processing Record 13 of Set 4 | quatre cocos
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | vieques
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | flinders
# Processing Record 22 of Set 4 | fort nelson
# Processing Record 23 of Set 4 | shubarshi
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | lubango
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | aswan
# Processing Record 29 of Set 4 | laguna
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | tessalit
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | kajaani
# Processing Record 36 of Set 4 | iisaku
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | dickinson
# Processing Record 40 of Set 4 | kununurra
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | walvis bay
# Processing Record 44 of Set 4 | tekkali
# Processing Record 45 of Set 4 | bahia honda
# Processing Record 46 of Set 4 | tarko-sale
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | ribnitz-damgarten
# Processing Record 50 of Set 4 | mokhsogollokh
# Processing Record 1 of Set 5 | churapcha
# Processing Record 2 of Set 5 | sao desiderio
# Processing Record 3 of Set 5 | east london
# Processing Record 4 of Set 5 | augustow
# Processing Record 5 of Set 5 | tunkas
# Processing Record 6 of Set 5 | richards bay
# Processing Record 7 of Set 5 | hermanus
# Processing Record 8 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 5 | lundazi
# Processing Record 10 of Set 5 | itacare
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | bethanien
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | yatou
# Processing Record 15 of Set 5 | onega
# Processing Record 16 of Set 5 | yumen
# Processing Record 17 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 5 | beatrice
# Processing Record 20 of Set 5 | henties bay
# Processing Record 21 of Set 5 | avarua
# Processing Record 22 of Set 5 | kiunga
# Processing Record 23 of Set 5 | betare oya
# Processing Record 24 of Set 5 | inta
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | manakara
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | wewak
# Processing Record 29 of Set 5 | homer
# Processing Record 30 of Set 5 | nuuk
# Processing Record 31 of Set 5 | vila do maio
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 5 | akdepe
# Processing Record 36 of Set 5 | krasnoselkup
# Processing Record 37 of Set 5 | alpena
# Processing Record 38 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 5 | sampit
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | riviere-au-renard
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | batticaloa
# Processing Record 44 of Set 5 | tepetitlan
# Processing Record 45 of Set 5 | oum hadjer
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | margate
# Processing Record 48 of Set 5 | yulara
# Processing Record 49 of Set 5 | yar-sale
# Processing Record 50 of Set 5 | glace bay
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | okhotsk
# Processing Record 4 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 6 | shumskiy
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | boyolangu
# Processing Record 8 of Set 6 | muhos
# Processing Record 9 of Set 6 | fortuna foothills
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | nalut
# Processing Record 13 of Set 6 | cape girardeau
# Processing Record 14 of Set 6 | sangar
# Processing Record 15 of Set 6 | varhaug
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | tonekabon
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | sorong
# Processing Record 20 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 6 | geneva
# Processing Record 22 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 6 | aklavik
# Processing Record 24 of Set 6 | sorkjosen
# Processing Record 25 of Set 6 | shediac
# Processing Record 26 of Set 6 | novopokrovka
# Processing Record 27 of Set 6 | kultayevo
# Processing Record 28 of Set 6 | palu
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | necochea
# Processing Record 32 of Set 6 | grajau
# Processing Record 33 of Set 6 | omboue
# Processing Record 34 of Set 6 | ahipara
# Processing Record 35 of Set 6 | sao jose da coroa grande
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | isla mujeres
# Processing Record 38 of Set 6 | coihaique
# Processing Record 39 of Set 6 | sur
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | toora-khem
# Processing Record 44 of Set 6 | korla
# Processing Record 45 of Set 6 | dakar
# Processing Record 46 of Set 6 | los llanos de aridane
# Processing Record 47 of Set 6 | naryan-mar
# Processing Record 48 of Set 6 | caravelas
# Processing Record 49 of Set 6 | raudeberg
# Processing Record 50 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 7 | yongan
# Processing Record 2 of Set 7 | derazhnya
# Processing Record 3 of Set 7 | koshurnikovo
# Processing Record 4 of Set 7 | marzuq
# Processing Record 5 of Set 7 | ust-kuyga
# Processing Record 6 of Set 7 | turkmenabat
# Processing Record 7 of Set 7 | venice
# Processing Record 8 of Set 7 | mar del plata
# Processing Record 9 of Set 7 | jiayuguan
# Processing Record 10 of Set 7 | zhezkazgan
# Processing Record 11 of Set 7 | azacualpa
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | beihai
# Processing Record 17 of Set 7 | suicheng
# Processing Record 18 of Set 7 | arraial do cabo
# Processing Record 19 of Set 7 | perth
# Processing Record 20 of Set 7 | toda bhim
# City not found. Skipping...
# Processing Record 21 of Set 7 | puri
# Processing Record 22 of Set 7 | saint anthony
# Processing Record 23 of Set 7 | faanui
# Processing Record 24 of Set 7 | dawlatabad
# Processing Record 25 of Set 7 | tokur
# Processing Record 26 of Set 7 | fairbanks
# Processing Record 27 of Set 7 | nanortalik
# Processing Record 28 of Set 7 | tura
# Processing Record 29 of Set 7 | bumba
# Processing Record 30 of Set 7 | turan
# Processing Record 31 of Set 7 | cap malheureux
# Processing Record 32 of Set 7 | concordia
# Processing Record 33 of Set 7 | kavieng
# Processing Record 34 of Set 7 | westport
# Processing Record 35 of Set 7 | pietersburg
# Processing Record 36 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 7 | riachao das neves
# Processing Record 38 of Set 7 | gilazi
# City not found. Skipping...
# Processing Record 39 of Set 7 | esperance
# Processing Record 40 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 7 | bilma
# Processing Record 42 of Set 7 | tocache
# Processing Record 43 of Set 7 | chaoyang
# Processing Record 44 of Set 7 | ubauro
# Processing Record 45 of Set 7 | bambous virieux
# Processing Record 46 of Set 7 | comodoro rivadavia
# Processing Record 47 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | shache
# Processing Record 50 of Set 7 | marquette
# Processing Record 1 of Set 8 | komatipoort
# Processing Record 2 of Set 8 | djambala
# Processing Record 3 of Set 8 | sola
# Processing Record 4 of Set 8 | bilibino
# Processing Record 5 of Set 8 | bereda
# Processing Record 6 of Set 8 | savyntsi
# Processing Record 7 of Set 8 | bahia blanca
# Processing Record 8 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 8 | saint-joseph
# Processing Record 10 of Set 8 | razole
# Processing Record 11 of Set 8 | saurimo
# Processing Record 12 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 8 | gigmoto
# Processing Record 16 of Set 8 | mahenge
# Processing Record 17 of Set 8 | cookshire
# City not found. Skipping...
# Processing Record 18 of Set 8 | vostochnyy
# Processing Record 19 of Set 8 | hambantota
# Processing Record 20 of Set 8 | sao filipe
# Processing Record 21 of Set 8 | eydhafushi
# Processing Record 22 of Set 8 | srikakulam
# Processing Record 23 of Set 8 | elban
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | salalah
# Processing Record 26 of Set 8 | thaba-tseka
# Processing Record 27 of Set 8 | huaraz
# Processing Record 28 of Set 8 | bud
# Processing Record 29 of Set 8 | san patricio
# Processing Record 30 of Set 8 | salamanca
# Processing Record 31 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 8 | oktyabrskiy
# Processing Record 33 of Set 8 | paita
# Processing Record 34 of Set 8 | belyy yar
# Processing Record 35 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 36 of Set 8 | hervey bay
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | glendive
# Processing Record 39 of Set 8 | tazovskiy
# Processing Record 40 of Set 8 | arlit
# Processing Record 41 of Set 8 | blythe
# Processing Record 42 of Set 8 | noumea
# Processing Record 43 of Set 8 | abu kamal
# Processing Record 44 of Set 8 | alice town
# Processing Record 45 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 8 | lusambo
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | oranjemund
# Processing Record 49 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 8 | bonavista
# Processing Record 1 of Set 9 | methoni
# Processing Record 2 of Set 9 | cockburn town
# Processing Record 3 of Set 9 | havre-saint-pierre
# Processing Record 4 of Set 9 | wenling
# Processing Record 5 of Set 9 | kota kinabalu
# Processing Record 6 of Set 9 | gat
# Processing Record 7 of Set 9 | corral nuevo
# Processing Record 8 of Set 9 | matagami
# Processing Record 9 of Set 9 | tasiilaq
# Processing Record 10 of Set 9 | ucluelet
# Processing Record 11 of Set 9 | bathsheba
# Processing Record 12 of Set 9 | umm kaddadah
# Processing Record 13 of Set 9 | batagay-alyta
# Processing Record 14 of Set 9 | siirt
# Processing Record 15 of Set 9 | thompson
# Processing Record 16 of Set 9 | palatka
# Processing Record 17 of Set 9 | sivaki
# Processing Record 18 of Set 9 | oksfjord
# Processing Record 19 of Set 9 | celestun
# Processing Record 20 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 9 | fortuna
# Processing Record 22 of Set 9 | tando muhammad khan
# Processing Record 23 of Set 9 | broken hill
# Processing Record 24 of Set 9 | kharp
# Processing Record 25 of Set 9 | brae
# Processing Record 26 of Set 9 | santa fe
# Processing Record 27 of Set 9 | corowa
# Processing Record 28 of Set 9 | nehe
# Processing Record 29 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 9 | balkanabat
# Processing Record 31 of Set 9 | teluknaga
# Processing Record 32 of Set 9 | ouadda
# Processing Record 33 of Set 9 | porto walter
# Processing Record 34 of Set 9 | bella vista
# Processing Record 35 of Set 9 | uk
# City not found. Skipping...
# Processing Record 36 of Set 9 | asyut
# Processing Record 37 of Set 9 | kidal
# Processing Record 38 of Set 9 | sadovoye
# Processing Record 39 of Set 9 | sena madureira
# Processing Record 40 of Set 9 | talara
# Processing Record 41 of Set 9 | kenai
# Processing Record 42 of Set 9 | sibolga
# Processing Record 43 of Set 9 | beloha
# Processing Record 44 of Set 9 | saint george
# Processing Record 45 of Set 9 | nabire
# Processing Record 46 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | novouzensk
# Processing Record 49 of Set 9 | hisor
# Processing Record 50 of Set 9 | fredericksburg
# Processing Record 1 of Set 10 | chicama
# Processing Record 2 of Set 10 | hyeres
# Processing Record 3 of Set 10 | northam
# Processing Record 4 of Set 10 | camana
# Processing Record 5 of Set 10 | krasnoturansk
# Processing Record 6 of Set 10 | maamba
# Processing Record 7 of Set 10 | bitam
# Processing Record 8 of Set 10 | kichera
# Processing Record 9 of Set 10 | taga
# Processing Record 10 of Set 10 | pevek
# Processing Record 11 of Set 10 | kanbe
# Processing Record 12 of Set 10 | lichuan
# Processing Record 13 of Set 10 | cabedelo
# Processing Record 14 of Set 10 | tomatlan
# Processing Record 15 of Set 10 | el retorno
# Processing Record 16 of Set 10 | eatonton
# Processing Record 17 of Set 10 | hasaki
# Processing Record 18 of Set 10 | biak
# Processing Record 19 of Set 10 | amahai
# Processing Record 20 of Set 10 | kosonsoy
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | wajima
# Processing Record 23 of Set 10 | namibe
# Processing Record 24 of Set 10 | ust-kulom
# Processing Record 25 of Set 10 | puerto varas
# Processing Record 26 of Set 10 | kakonko
# Processing Record 27 of Set 10 | baisha
# Processing Record 28 of Set 10 | murray bridge
# Processing Record 29 of Set 10 | yerbogachen
# Processing Record 30 of Set 10 | enshi
# Processing Record 31 of Set 10 | ewa beach
# Processing Record 32 of Set 10 | santa maria
# Processing Record 33 of Set 10 | mokolo
# Processing Record 34 of Set 10 | snyder
# Processing Record 35 of Set 10 | navrongo
# Processing Record 36 of Set 10 | soyo
# Processing Record 37 of Set 10 | tallahassee
# Processing Record 38 of Set 10 | teluk nibung
# Processing Record 39 of Set 10 | imbituba
# Processing Record 40 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 10 | sechura
# Processing Record 42 of Set 10 | rumphi
# Processing Record 43 of Set 10 | amuntai
# Processing Record 44 of Set 10 | mandan
# Processing Record 45 of Set 10 | jeremie
# Processing Record 46 of Set 10 | la ronge
# Processing Record 47 of Set 10 | nouakchott
# Processing Record 48 of Set 10 | srednekolymsk
# Processing Record 49 of Set 10 | ye
# City not found. Skipping...
# Processing Record 50 of Set 10 | saint-augustin
# Processing Record 1 of Set 11 | maisuru
# City not found. Skipping...
# Processing Record 2 of Set 11 | sosnovo-ozerskoye
# Processing Record 3 of Set 11 | kungurtug
# Processing Record 4 of Set 11 | pak phanang
# Processing Record 5 of Set 11 | abu dhabi
# Processing Record 6 of Set 11 | mocuba
# Processing Record 7 of Set 11 | pantayivka
# Processing Record 8 of Set 11 | nkoteng
# Processing Record 9 of Set 11 | muros
# Processing Record 10 of Set 11 | kapoeta
# Processing Record 11 of Set 11 | jiazi
# Processing Record 12 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 11 | omaruru
# Processing Record 14 of Set 11 | sept-iles
# Processing Record 15 of Set 11 | ust-maya
# Processing Record 16 of Set 11 | gairo
# Processing Record 17 of Set 11 | wanaka
# Processing Record 18 of Set 11 | hamilton
# Processing Record 19 of Set 11 | burnie
# Processing Record 20 of Set 11 | alberton
# Processing Record 21 of Set 11 | nioaque
# Processing Record 22 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 11 | port keats
# Processing Record 24 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 11 | auki
# Processing Record 26 of Set 11 | kitimat
# Processing Record 27 of Set 11 | paratinga
# Processing Record 28 of Set 11 | alice springs
# Processing Record 29 of Set 11 | coahuayana
# Processing Record 30 of Set 11 | kiruna
# Processing Record 31 of Set 11 | rocha
# Processing Record 32 of Set 11 | sumbe
# Processing Record 33 of Set 11 | touros
# Processing Record 34 of Set 11 | poretskoye
# Processing Record 35 of Set 11 | lata
# Processing Record 36 of Set 11 | morondava
# Processing Record 37 of Set 11 | formosa
# Processing Record 38 of Set 11 | pingzhuang
# Processing Record 39 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 11 | oskarshamn
# Processing Record 41 of Set 11 | aksu
# Processing Record 42 of Set 11 | zlobin
# Processing Record 43 of Set 11 | itambe
# Processing Record 44 of Set 11 | sterling
# Processing Record 45 of Set 11 | fengxian
# Processing Record 46 of Set 11 | narsaq
# Processing Record 47 of Set 11 | waharoa
# Processing Record 48 of Set 11 | las lomas
# Processing Record 49 of Set 11 | portland
# Processing Record 50 of Set 11 | olafsvik
# Processing Record 1 of Set 12 | ilo
# Processing Record 2 of Set 12 | chauk
# Processing Record 3 of Set 12 | garowe
# Processing Record 4 of Set 12 | tuensang
# Processing Record 5 of Set 12 | vao
# Processing Record 6 of Set 12 | abha
# Processing Record 7 of Set 12 | vagay
# Processing Record 8 of Set 12 | bogorodskoye
# Processing Record 9 of Set 12 | kurganinsk
# Processing Record 10 of Set 12 | chifeng
# Processing Record 11 of Set 12 | bagaha
# Processing Record 12 of Set 12 | vitim
# Processing Record 13 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 12 | mecca
# Processing Record 15 of Set 12 | saint-francois
# Processing Record 16 of Set 12 | camacari
# Processing Record 17 of Set 12 | micheweni
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | pirassununga
# Processing Record 20 of Set 12 | vostok
# Processing Record 21 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 22 of Set 12 | daru
# Processing Record 23 of Set 12 | bahir dar
# Processing Record 24 of Set 12 | bellevue
# Processing Record 25 of Set 12 | egvekinot
# Processing Record 26 of Set 12 | altea
# Processing Record 27 of Set 12 | myre
# Processing Record 28 of Set 12 | valdivia
# Processing Record 29 of Set 12 | winslow
# Processing Record 30 of Set 12 | talcahuano
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | sao joao da barra
# Processing Record 33 of Set 12 | nizwa
# Processing Record 34 of Set 12 | emerald
# Processing Record 35 of Set 12 | sadat
# Processing Record 36 of Set 12 | manono
# Processing Record 37 of Set 12 | uruzgan
# Processing Record 38 of Set 12 | basoko
# Processing Record 39 of Set 12 | saint-leu
# Processing Record 40 of Set 12 | kalmunai
# Processing Record 41 of Set 12 | najran
# Processing Record 42 of Set 12 | atikokan
# Processing Record 43 of Set 12 | west plains
# Processing Record 44 of Set 12 | kajiado
# Processing Record 45 of Set 12 | manpur
# Processing Record 46 of Set 12 | jhalawar
# Processing Record 47 of Set 12 | nioro
# Processing Record 48 of Set 12 | hobbs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len (city_data)
# Out:
# 540

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Kudymkar  59.0173   54.6560     57.06        79           7        1.90
# 1         Doha  25.2867   51.5333     89.58        79          20       11.50
# 2        Ancud -41.8697  -73.8203     47.52        79         100        4.97
# 3     Katsuura  35.1333  140.3000     79.38        91          64        8.99
# 4  Tuktoyaktuk  69.4541 -133.0374     44.60        93         100       10.36
# 5    Busselton -33.6500  115.3333     59.81        83         100       18.52
# 6  Port Alfred -33.5906   26.8910     63.18        86           1       14.07
# 7      Bairiki   1.3292  172.9752     80.60        83          20        9.22
# 8       Albany  42.6001  -73.9662     90.05        56         100        7.49
# 9    Jiaocheng  24.6774  116.1389     75.65        89          66        1.19
#
#   Weather Discription Country                 Date
# 0           clear sky      RU  2022-07-28 19:53:19
# 1          few clouds      QA  2022-07-28 19:48:29
# 2     overcast clouds      CL  2022-07-28 19:53:20
# 3       broken clouds      JP  2022-07-28 19:50:42
# 4          light rain      CA  2022-07-28 19:49:43
# 5     overcast clouds      AU  2022-07-28 19:53:21
# 6           clear sky      ZA  2022-07-28 19:53:22
# 7          few clouds      KI  2022-07-28 19:53:22
# 8     overcast clouds      US  2022-07-28 19:50:23
# 9       broken clouds      CN  2022-07-28 19:53:23

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Discription']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Kudymkar      RU  2022-07-28 19:53:19  59.0173   54.6560     57.06
# 1         Doha      QA  2022-07-28 19:48:29  25.2867   51.5333     89.58
# 2        Ancud      CL  2022-07-28 19:53:20 -41.8697  -73.8203     47.52
# 3     Katsuura      JP  2022-07-28 19:50:42  35.1333  140.3000     79.38
# 4  Tuktoyaktuk      CA  2022-07-28 19:49:43  69.4541 -133.0374     44.60
# 5    Busselton      AU  2022-07-28 19:53:21 -33.6500  115.3333     59.81
# 6  Port Alfred      ZA  2022-07-28 19:53:22 -33.5906   26.8910     63.18
# 7      Bairiki      KI  2022-07-28 19:53:22   1.3292  172.9752     80.60
# 8       Albany      US  2022-07-28 19:50:23  42.6001  -73.9662     90.05
# 9    Jiaocheng      CN  2022-07-28 19:53:23  24.6774  116.1389     75.65
#
#    Humidity  Cloudiness  Wind Speed Weather Discription
# 0        79           7        1.90           clear sky
# 1        79          20       11.50          few clouds
# 2        79         100        4.97     overcast clouds
# 3        91          64        8.99       broken clouds
# 4        93         100       10.36          light rain
# 5        83         100       18.52     overcast clouds
# 6        86           1       14.07           clear sky
# 7        83          20        9.22          few clouds
# 8        56         100        7.49     overcast clouds
# 9        89          66        1.19       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
